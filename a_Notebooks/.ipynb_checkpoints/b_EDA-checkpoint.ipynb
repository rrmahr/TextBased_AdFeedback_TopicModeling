# %% [markdown]
# ## Text-Based Ad Feedback Topic Modeling: EDA<br>

# %% [markdown]
# ### TOC
# * [Step 1: Load Data & Formatting](#1)
# * [Step 2: EDA of Sample Distribution](#2)
# * [Step 3: Tokenize & Remove Stopwords](#3)
# * [Step 4: Lemmatize](#4)
# * [Step 5: Term Frequency Analysis](#5)
# * [Step 6: Sentiment Analysis](#6)
# * [Step 7: Summary & Next Steps](#7)

# %% [markdown]
# ### Step 1: Load Data and Formatting   <a class="anchor" id="1"></a>

# %%
#Load Packages
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
from textblob import TextBlob
from wordcloud import WordCloud, ImageColorGenerator
import re
import spacy
import en_core_web_sm
from spacy.tokenizer import Tokenizer
import gensim
from gensim.parsing.preprocessing import STOPWORDS as SW
from wordcloud import STOPWORDS
stopwords = set(STOPWORDS)
from nltk.probability import FreqDist
import qgrid
import warnings
warnings.filterwarnings('ignore')

# %%
#Open data
clean_df = pd.read_csv('../Datafiles/Feedback_df_clean.csv')

# %%
#Inspect raw feedback file
print(clean_df.info())
clean_df.sort_values(by='Text_Clean')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4338 entries, 0 to 4337
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ID             4338 non-null   object
#  1   Text_Original  4338 non-null   object
#  2   Ad             4338 non-null   object
#  3   Question       4338 non-null   object
#  4   Age            4338 non-null   int64
#  5   Race           4338 non-null   object
#  6   Segment        4338 non-null   int64
#  7   Urban          4338 non-null   int64
#  8   Female         4338 non-null   int64
#  9   Region_1       4338 non-null   int64
#  10  Text_Clean     4338 non-null   object
# dtypes: int64(5), object(6)
# memory usage: 372.9+ KB
# None
#                      ID                                      Text_Original  \
# 0     R_eS4NGrnSGSYTxSh                               A little informative
# 1     R_31EnmC82PmXgfeJ  A lot of chemicals are in vapes that damage th...
# 2     R_xniZkHbwJjrCac1                   a lot of information all at once
# 3     R_2UVKzhgLoqvkyzk  A method of discouragement against vaping by i...
# 4     R_2PC3MSRmAF3ln2c                      About the ingredients in vape
# ...                 ...                                                ...
# 4332  R_yD55zMWP70MfIJj  young adults should stop vaping and should onl...
# 4333  R_1NtzYydKbITQGGx  young adults who vape are more susceptible to ...
# 4334  R_1Neo5BRW5uKrCo1        Young people shouldn’t be addicted to vapes
# 4335  R_2BeXLWlBMeOG01L  Younger people need to stop being fooled, comp...
# 4336  R_27QKefTaktUGMb3  Your hurting yourself and should quit with a l...
#
#       Ad      Question  Age        Race  Segment  Urban  Female  Region_1  \
# 0     DF         Likes   18  White Only        5      1       0         1
# 1     DF  Main Message   17  White Only        1      1       0         1
# 2     DF      Dislikes   17  White Only        5      1       0         0
# 3     DD  Main Message   18  White Only        4      0       0         0
# 4     ST  Main Message   18  White Only        1      1       1         0
# ...   ..           ...  ...         ...      ...    ...     ...       ...
# 4332  ST  Main Message   18  White Only        1      1       1         1
# 4333  DF  Main Message   17  White Only        6      0       1         1
# 4334  DF  Main Message   18  White Only        1      0       1         0
# 4335  DD  Main Message   18  White Only        5      0       0         1
# 4336  DF  Main Message   16  White Only        5      0       0         1
#
#                                              Text_Clean
# 0                                  a little informative
# 1     a lot of chemicals are in vapes that damage th...
# 2                      a lot of information all at once
# 3     a method of discouragement against vaping by i...
# 4                         about the ingredients in vape
# ...                                                 ...
# 4332  young adults should stop vaping and should onl...
# 4333  young adults who vape are more susceptible to ...
# 4334       young people should not be addicted to vapes
# 4335  younger people need to stop being fooled  comp...
# 4336  your hurting yourself and should quit with a l...
#
# [4338 rows x 11 columns]

# %% [markdown]
# ### Step 2: EDA of Sample Distribution <a class="anchor" id="2"></a>
# * Let's look at just the sample demos df that was merged into the feedback df in the wrangling step

# %%
#Load data
demos_df = pd.read_csv('../Datafiles/AD_FEEDBACK_DEMOS_Processed.csv')
print(demos_df.info())
demos_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 724 entries, 0 to 723
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ID        724 non-null    object
#  1   Age       724 non-null    int64
#  2   Race      724 non-null    object
#  3   Segment   724 non-null    int64
#  4   Urban     724 non-null    int64
#  5   Female    724 non-null    int64
#  6   Region_1  724 non-null    int64
# dtypes: int64(5), object(2)
# memory usage: 39.7+ KB
# None
#                   ID  Age        Race  Segment  Urban  Female  Region_1
# 0  R_1pA46rQimTRsAXQ   17  White Only        5      1       0         1
# 1  R_1HdhEhdQGzgDkre   17  White Only        5      1       0         1
# 2  R_Rab5MQj0TqGqV4R   18  White Only        4      0       1         1
# 3  R_2uVXBpLsewn1Snv   16  White Only        5      1       1         1
# 4  R_2ymgqdHCNQnDOru   18  White Only        4      0       1         1

# %%
#Look at descriptives for Age (only continuous var)
demos_df['Age'].describe()
# Out:
# count    724.000000
# mean      16.649171
# std        1.401881
# min       13.000000
# 25%       16.000000
# 50%       17.000000
# 75%       18.000000
# max       19.000000
# Name: Age, dtype: float64

# %% [markdown]
# #### Notes:
# * n=724 survey participants
# * Average Age: 16.7, Median Age = 17

# %%
#Color palette for visualizations
color_palette = ['midnightblue','#24478f','steelblue','#7FB3D5','skyblue','#b3e0ff'] 

#Create function to develop histograms with % labels above each bar
def pretty_bar(column,figsize,colors):
    '''
    Creates function to develop histogram with % labels above each bar
    with aligned bars and labels
    Customize figsize -- must be: (w,h)
    Customize color options: 
        https://matplotlib.org/stable/gallery/color/named_colors.html
        https://www.w3schools.com/colors/colors_picker.asp
    '''
    y = np.array(list(column.value_counts())) #bar heights
    
    #Loop below creates the percentage labels
    y_percents = list(round(column.value_counts(normalize=True) *100,1))
    y_perlabs = []
    for i in y_percents: 
        y_perlabs.append(str(i)+'%')
    y_perlabs = np.array(y_perlabs)
    
    x = column.unique() #x-axis points
    
    plt.subplots(figsize=figsize)
    plt.bar(x, y, align='center', color=colors) #actual bar plot setup

    # Text on the top of each bar, 
    # Code for below adapted from https://www.python-graph-gallery.com/10-barplot-with-number-of-observation
    for i in range(len(x)):
        plt.text(x = x[i] , y = y[i]+5, s=y_perlabs[i])

# %%
#Bar plot for Age
pretty_bar(demos_df['Age'],(16,6),color_palette)
plt.style.use('seaborn-colorblind')
plt.title('Age Distribution')
plt.ylabel('Sample Count')
plt.show()

# %%
#Bar plot for Gender
pretty_bar(demos_df['Female'],(15,5),color_palette)
plt.style.use('seaborn-colorblind')
plt.title('Gender Distribution: 0 = Female')
plt.ylabel('Sample Count')
plt.show()

# %%
#Bar plot for Race
pretty_bar(demos_df['Race'],(15,5),color_palette)
plt.style.use('seaborn-colorblind')
plt.title('Race Distribution')
plt.ylabel('Sample Count')
plt.show()

# %%
#Bar plot for Segment
pretty_bar(demos_df['Segment'],(15,5),color_palette)
plt.style.use('seaborn-colorblind')
plt.title('Segment Distribution')
plt.ylabel('Sample Count')
plt.show()

# %%
#Bar plot for Urban
pretty_bar(demos_df['Urban'],(10,5),color_palette)
plt.style.use('seaborn-colorblind')
plt.title('Urban (1) vs. Rural (0) Distribution')
plt.ylabel('Sample Count')
plt.show()

# %%
#Bar plot for Region_1
pretty_bar(demos_df['Region_1'],(10,5),color_palette)
plt.style.use('seaborn-colorblind')
plt.title('Region Distribution')
plt.ylabel('Sample Count')
plt.show()

# %% [markdown]
# ### Step 3: Tokenize & Remove Stopwords <a class="anchor" id="3"></a>
# Source: Adapted from a Towards Data Science article posted by Amin Azad at https://towardsdatascience.com/twitter-topic-modeling-e0e3315b12e2, retrieved in January 2021.
#
# * Selected spacy for tokenization over nltk for its ability to 'construct a syntactic tree' which 'yields much more information about the text.' -- According to: https://medium.com/@akankshamalhotra24/introduction-to-libraries-of-nlp-in-python-nltk-vs-spacy-42d7b2f128f2#:~:text=NLTK%20is%20a%20string%20processing%20library.&text=As%20spaCy%20uses%20the%20latest,sentence%20tokenization%2C%20NLTK%20outperforms%20spaCy
# <br><br>
# * For now, we'll just apply basic tokenization & lemmatization for EDA of term frequency

# %%
# Load spacy
nlp = en_core_web_sm.load()

# %%
# Tokenizer
tokenizer = Tokenizer(nlp.vocab)


#Not adding custom stopwords right now -- just initial check
'''#Custom stopwords
custom_stopwords = ['']

# Customize stop words by adding to the default list
STOP_WORDS = nlp.Defaults.stop_words.union(custom_stopwords)
'''
STOP_WORDS = nlp.Defaults.stop_words

# ALL_STOP_WORDS = spacy + gensim + wordcloud
ALL_STOP_WORDS = STOP_WORDS.union(SW).union(stopwords)

tokens = []

for doc in tokenizer.pipe(clean_df['Text_Clean'], batch_size=500):
    doc_tokens = []    
    for token in doc: 
        if token.text.lower() not in stopwords:
            doc_tokens.append(token.text.lower())   
    tokens.append(doc_tokens)

# Makes tokens column

clean_df['tokens'] = tokens
clean_df.head()
# Out:
#                   ID                                      Text_Original  Ad  \
# 0  R_eS4NGrnSGSYTxSh                               A little informative  DF
# 1  R_31EnmC82PmXgfeJ  A lot of chemicals are in vapes that damage th...  DF
# 2  R_xniZkHbwJjrCac1                   a lot of information all at once  DF
# 3  R_2UVKzhgLoqvkyzk  A method of discouragement against vaping by i...  DD
# 4  R_2PC3MSRmAF3ln2c                      About the ingredients in vape  ST
#
#        Question  Age        Race  Segment  Urban  Female  Region_1  \
# 0         Likes   18  White Only        5      1       0         1
# 1  Main Message   17  White Only        1      1       0         1
# 2      Dislikes   17  White Only        5      1       0         0
# 3  Main Message   18  White Only        4      0       0         0
# 4  Main Message   18  White Only        1      1       1         0
#
#                                           Text_Clean  \
# 0                               a little informative
# 1  a lot of chemicals are in vapes that damage th...
# 2                   a lot of information all at once
# 3  a method of discouragement against vaping by i...
# 4                      about the ingredients in vape
#
#                                               tokens
# 0                              [little, informative]
# 1  [lot, chemicals, vapes, damage, lungs, make, s...
# 2                                 [lot, information]
# 3  [method, discouragement, vaping, intending, ma...
# 4                                [ingredients, vape]

# %% [markdown]
# ### Step 4: Lemmatize <a class="anchor" id="4"></a>
# Source: Adapted from a Towards Data Science article posted by Amin Azad at https://towardsdatascience.com/twitter-topic-modeling-e0e3315b12e2, retrieved in January 2021.
# * Using spaCy here as well determines the part-of-speech tag by default and assigns the corresponding lemma.

# %%
#Make tokens a string again
clean_df['tokens_string'] = [' '.join(map(str, l)) for l in clean_df['tokens']]

def get_lemmas(text):
    '''Used to lemmatize the processed tweets'''
    lemmas = []
    
    doc = nlp(text)
    
    # Something goes here :P
    for token in doc: 
        if ((token.is_stop == False) and (token.is_punct == False)) and (token.pos_ != 'PRON'):
            lemmas.append(token.lemma_)
    
    return lemmas

clean_df['lemmas'] = clean_df['tokens_string'].apply(get_lemmas)

# %%
# Make lemmas a string again
clean_df['lem_text'] = [' '.join(map(str, l)) for l in clean_df['lemmas']]

#Delete extra vars, just keep tokenized lemmas and lematized text
clean_df = clean_df.drop(columns = ['tokens','tokens_string'])
clean_df = clean_df.rename(columns = {'lemmas':'Text_Token', 'lem_text':'Text_Lemmas'})

# %%
#Check results
clean_df = clean_df.sort_values(by='Text_Lemmas')
clean_df.head()
# Out:
#                      ID Text_Original  Ad  Question  Age  \
# 2168  R_3hhCLQqJrstLp6K       Nothing  ST  Dislikes   14
# 1812  R_2VO7QMDMyGx9N8w          None  DF     Likes   18
# 1813  R_5d5utDxwTbj9ko9          None  DF  Dislikes   15
# 1814  R_Dw6PTGMRz6b5Zip          None  DF  Dislikes   16
# 1815  R_2bQtkkHEj8tUy7B          None  DF  Dislikes   18
#
#                             Race  Segment  Urban  Female  Region_1 Text_Clean  \
# 2168                  Asian Only        4      1       1         0    nothing
# 1812  Two or More - Non Hispanic        2      1       0         1       none
# 1813                  White Only        1      1       0         1       none
# 1814                  White Only        4      1       1         1       none
# 1815                  Black Only        5      1       1         1       none
#
#      Text_Token Text_Lemmas
# 2168         []
# 1812         []
# 1813         []
# 1814         []
# 1815         []

# %% [markdown]
# #### Notes:
# * Potential words to add to stopwords list for processing:
#     * 'nothing', 'none', 'like', 'everything','anything'
#     * Although the above stop words make sense to exclude in NLP, in this use case, these words are relevant answers to 'Likes' and 'Dislikes' quesitons
# * May want to split out the likes, dislikes and messages for processing & modeling

# %% [markdown]
# ### Step 5: Text Frequency Analysis<a class="anchor" id="5"></a>
# Source: Term Frequency Analysis and WordCloud code adapted from Towards Data Science article by Kamil Mysiak at https://towardsdatascience.com/nlp-part-3-exploratory-data-analysis-of-text-data-1caa8ab3f79d retrieved in January, 2021.

# %%
#Splitting text responses based on question

message_df = clean_df[clean_df['Question']=='Main Message'].copy()
print('Messages DF Values')
print(message_df['Question'].value_counts())

likes_df = clean_df[clean_df['Question']=='Likes'].copy()
print('Likes DF Values')
print(likes_df['Question'].value_counts())

dislikes_df = clean_df[clean_df['Question']=='Dislikes'].copy()
print('Dislikes DF Values')
print(dislikes_df['Question'].value_counts())
# Out:
# Messages DF Values
# Main Message    1448
# Name: Question, dtype: int64
# Likes DF Values
# Likes    1445
# Name: Question, dtype: int64
# Dislikes DF Values
# Dislikes    1445
# Name: Question, dtype: int64

# %% [markdown]
# #### Main Message Feedback Text Frequency

# %%
#Create word list
words = message_df['Text_Token']
allwords = []
for wordlist in words:
    allwords += wordlist

# %%
#Inspect and edit word list to remove any stopwords or punctuation missed in cleaning
FreqDist(allwords).most_common(150)
# Out:
# [('vape', 1078),
#  ('company', 204),
#  ('  ', 154),
#  ('virus', 144),
#  ('people', 127),
#  ('stop', 126),
#  ('teen', 126),
#  ('bad', 121),
#  ('smoke', 114),
#  ('lie', 104),
#  ('body', 102),
#  ('lung', 99),
#  ('harmful', 97),
#  ('system', 89),
#  ('immune', 85),
#  ('make', 81),
#  ('chemical', 77),
#  ('target', 70),
#  ('damage', 64),
#  ('juul', 63),
#  ('vaping', 61),
#  ('health', 56),
#  ('sick', 51),
#  ('product', 48),
#  ('harm', 48),
#  ('dangerous', 47),
#  ('young', 46),
#  ('susceptible', 46),
#  ('try', 44),
#  ('know', 42),
#  ('risk', 42),
#  ('weaken', 41),
#  ('vulnerable', 40),
#  ('fight', 37),
#  ('safe', 35),
#  ('kid', 34),
#  ('disease', 32),
#  ('break', 31),
#  ('inform', 30),
#  ('s', 30),
#  ('tell', 27),
#  ('addict', 27),
#  ('ability', 27),
#  ('message', 25),
#  ('likely', 25),
#  ('quit', 25),
#  ('main', 24),
#  ('get', 23),
#  ('effect', 23),
#  ('smoking', 23),
#  ('cause', 22),
#  ('truth', 22),
#  ('customer', 22),
#  ('easy', 22),
#  ('think', 22),
#  ('infection', 21),
#  ('good', 19),
#  ('covid', 19),
#  ('thing', 18),
#  ('weak', 17),
#  ('addicted', 17),
#  ('sell', 17),
#  ('leave', 16),
#  ('contain', 16),
#  ('danger', 16),
#  ('put', 16),
#  ('money', 15),
#  ('ingredient', 15),
#  ('inhale', 15),
#  ('hurt', 15),
#  ('lead', 15),
#  ('healthy', 14),
#  ('illness', 14),
#  ('sickness', 13),
#  ('want', 13),
#  ('generation', 13),
#  ('market', 13),
#  ('let', 12),
#  ('buy', 12),
#  ('say', 12),
#  ('advertisement', 12),
#  ('advertise', 12),
#  ('nicotine', 12),
#  ('underage', 12),
#  ('harmless', 12),
#  ('use', 12),
#  ('spread', 12),
#  ('information', 12),
#  ('show', 12),
#  ('catch', 11),
#  ('kill', 11),
#  ('vapor', 11),
#  ('affect', 11),
#  ('prone', 11),
#  ('tobacco', 10),
#  ('believe', 10),
#  ('child', 10),
#  ('cape', 10),
#  ('addiction', 10),
#  ('expose', 10),
#  ('high', 10),
#  ('increase', 10),
#  ('ad', 9),
#  ('time', 9),
#  ('lot', 9),
#  ('big', 9),
#  ('help', 9),
#  ('germ', 9),
#  ('cigarette', 9),
#  ('especially', 9),
#  ('need', 9),
#  ('lower', 9),
#  ('actually', 8),
#  ('industry', 8),
#  ('give', 8),
#  ('adult', 8),
#  ('youth', 8),
#  ('19', 8),
#  ('easily', 7),
#  ('start', 7),
#  ('new', 7),
#  ('way', 7),
#  ('flavor', 7),
#  ('profit', 7),
#  ('create', 7),
#  ('die', 7),
#  ('fact', 7),
#  ('go', 7),
#  ('deadly', 7),
#  ('toxic', 7),
#  ('care', 7),
#  ('consumer', 7),
#  ('safety', 7),
#  ('look', 7),
#  ('cellular', 6),
#  ('protect', 6),
#  ('defense', 6),
#  ('encourage', 6),
#  ('order', 6),
#  ('fun', 6),
#  ('drug', 6),
#  ('real', 6),
#  ('false', 6),
#  ('hard', 6),
#  ('warn', 6),
#  ('level', 6),
#  ('prevent', 6),
#  ('downplay', 6),
#  ('chance', 6),
#  ('poison', 6)]

# %%
#Edited list
words = message_df['Text_Token']
allwords = []
for wordlist in words:
    if "  " not in wordlist and "s" not in wordlist:
        allwords += wordlist

# %%
#Create word cloud
mostcommon = FreqDist(allwords).most_common(50)
wordcloud = WordCloud(width=600, height=300,
background_color='white').generate(str(mostcommon))
fig = plt.figure(figsize=(20,6.5), facecolor='white')
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.title('Top 50 Most Common Words - Main Message', fontsize=32)
plt.tight_layout(pad=0)
plt.show()

# %%
#Create function for word frequency bar plots

def word_bar(x,y,figsize,colors):
    #Loop below creates the percentage labels
    y_percents = []
    for i in y:
        y_percents.append((round((i / (np.sum(y))) *100,1)))
    
    y_perlabs = []
    for i in y_percents: 
        y_perlabs.append(str(i)+'%')
    y_perlabs = np.array(y_perlabs)
    
    x = x
    
    plt.subplots(figsize=figsize)
    plt.bar(x, y, align='center', color=colors) #actual bar plot setup
    plt.xticks(rotation=60)


    # Text on the top of each bar, 
    # Code for below adapted from https://www.python-graph-gallery.com/10-barplot-with-number-of-observation
    for i in range(len(x)):
        plt.text(x = x[i] , y = y[i]+0.5, s=y_perlabs[i])

# %%
mostcommon_small = FreqDist(allwords).most_common(30)
x, y = zip(*mostcommon_small)
        
word_bar(x,y,(20,8),color_palette)
plt.style.use('seaborn-colorblind')
plt.title('Top 30 Most Common Words - Main Message')
plt.ylabel('Count of Words')
plt.show()

# %% [markdown]
# #### Notes:
# * Ad video messages related to:
#     * chemicals in vapes
#     * vapes making smokers vulnerable to viruses/illness
#     * vape companies deceiving teens
# * Most common words in response to main message include:
#     * vape - likely related to all -- might exclude in processing
#     * company, teen, people
#     * chemical, harmful, lung
#     * virus, immune

# %% [markdown]
# #### Likes Feedback Text Frequency

# %%
#Create word list
words = likes_df['Text_Token']
allwords = []
for wordlist in words:
    allwords += wordlist

# %%
#Inspect and edit word list to remove any stopwords or punctuation missed in cleaning
FreqDist(allwords).most_common(150)
# Out:
# [('  ', 223),
#  ('vape', 177),
#  ('animation', 137),
#  ('show', 123),
#  ('message', 94),
#  ('fact', 89),
#  ('visual', 74),
#  ('point', 73),
#  ('informative', 68),
#  ('graphic', 62),
#  ('tell', 59),
#  ('information', 56),
#  ('give', 53),
#  ('good', 51),
#  ('people', 51),
#  ('like', 49),
#  ('company', 48),
#  ('teen', 47),
#  ('cartoon', 47),
#  ('style', 42),
#  ('lung', 42),
#  ('truth', 39),
#  ('short', 38),
#  ('body', 36),
#  ('know', 33),
#  ('chemical', 33),
#  ('clear', 32),
#  ('attention', 30),
#  ('way', 30),
#  ('use', 29),
#  ('art', 28),
#  ('straight', 28),
#  ('try', 26),
#  ('example', 26),
#  ('say', 25),
#  ('nice', 25),
#  ('get', 24),
#  ('color', 24),
#  ('cool', 23),
#  ('vaping', 23),
#  ('virus', 23),
#  ('ad', 22),
#  ('specific', 22),
#  ('understand', 21),
#  ('real', 21),
#  ('happen', 21),
#  ('present', 21),
#  ('catch', 20),
#  ('explain', 20),
#  ('voice', 20),
#  ('bad', 19),
#  ('easy', 19),
#  ('smoke', 19),
#  ('lie', 19),
#  ('simple', 18),
#  ('advertisement', 18),
#  ('young', 18),
#  ('make', 18),
#  ('video', 18),
#  ('evidence', 18),
#  ('harmful', 18),
#  ('target', 17),
#  ('detail', 17),
#  ('relatable', 17),
#  ('effect', 16),
#  ('go', 16),
#  ('expose', 15),
#  ('inform', 15),
#  ('grab', 15),
#  ('stop', 15),
#  ('risk', 14),
#  ('danger', 14),
#  ('eye', 14),
#  ('thing', 14),
#  ('article', 14),
#  ('word', 13),
#  ('look', 12),
#  ('lot', 12),
#  ('quote', 12),
#  ('provide', 12),
#  ('kid', 12),
#  ('picture', 12),
#  ('talk', 12),
#  ('source', 11),
#  ('change', 11),
#  ('damage', 11),
#  ('convince', 11),
#  ('quick', 10),
#  ('spread', 10),
#  ('animate', 10),
#  ('narrator', 10),
#  ('inside', 10),
#  ('think', 10),
#  ('truthful', 9),
#  ('state', 9),
#  ('interesting', 9),
#  ('juul', 9),
#  ('want', 9),
#  ('harm', 9),
#  ('ingredient', 8),
#  ('pandemic', 8),
#  ('straightforward', 8),
#  ('system', 8),
#  ('appeal', 8),
#  ('affect', 8),
#  ('visually', 8),
#  ('help', 8),
#  ('dead', 8),
#  ('colorful', 8),
#  ('image', 8),
#  ('list', 8),
#  ('relate', 8),
#  ('love', 8),
#  ('health', 8),
#  ('strong', 8),
#  ('pretty', 7),
#  ('actually', 7),
#  ('audience', 7),
#  ('little', 7),
#  ('design', 7),
#  ('info', 7),
#  ('clearly', 7),
#  ('stuff', 7),
#  ('dangerous', 7),
#  ('harmless', 7),
#  ('listen', 7),
#  ('smoking', 7),
#  ('sound', 7),
#  ('watch', 6),
#  ('claim', 6),
#  ('reason', 6),
#  ('viewer', 6),
#  ('direct', 6),
#  ('main', 6),
#  ('draw', 6),
#  ('transition', 6),
#  ('call', 6),
#  ('display', 6),
#  ('newspaper', 6),
#  ('effective', 6),
#  ('statement', 6),
#  ('representation', 6),
#  ('enter', 6),
#  ('true', 6),
#  ('news', 6),
#  ('honest', 6),
#  ('hurt', 6),
#  ('covid', 6),
#  ('feel', 5),
#  ('speaker', 5)]

# %%
#Edited list - excluding spaces and vape because vape is just the topic of the videos
words = likes_df['Text_Token']
allwords = []
for wordlist in words:
    if "  " not in wordlist and "s" not in wordlist and "vape" not in wordlist:
        allwords += wordlist

# %%
#Create word cloud
mostcommon = FreqDist(allwords).most_common(50)
wordcloud = WordCloud(width=600, height=300,
background_color='white').generate(str(mostcommon))
fig = plt.figure(figsize=(20,6.5), facecolor='white')
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.title('Top 50 Most Common Words - Likes', fontsize=28)
plt.tight_layout(pad=0)
plt.show()

# %%
mostcommon_small = FreqDist(allwords).most_common(30)
x, y = zip(*mostcommon_small)
        
word_bar(x,y,(20,8),color_palette)
plt.style.use('seaborn-colorblind')
plt.title('Top 30 Most Common Words - Likes')
plt.ylabel('Count of Words')
plt.show()

# %% [markdown]
# #### Notes:
# * Top words in Likes feedback:
#     * animation, show, visual
#     * message, point
#     * informative/information, fact
# * Consider removing 'like' in preprocessing

# %% [markdown]
# #### Dislikes Feedback Text Frequency

# %%
#Create word list
words = dislikes_df['Text_Token']
allwords = []
for wordlist in words:
    allwords += wordlist

# %%
#Inspect and edit word list to remove any stopwords or punctuation missed in cleaning
FreqDist(allwords).most_common(150)
# Out:
# [('  ', 324),
#  ('dislike', 112),
#  ('vape', 87),
#  ('people', 56),
#  ('kind', 49),
#  ('little', 49),
#  ('ad', 48),
#  ('think', 48),
#  ('know', 43),
#  ('teen', 41),
#  ('good', 39),
#  ('voice', 37),
#  ('video', 37),
#  ('animation', 36),
#  ('feel', 34),
#  ('understand', 33),
#  ('advertisement', 31),
#  ('fact', 30),
#  ('information', 28),
#  ('message', 27),
#  ('go', 27),
#  ('way', 26),
#  ('bit', 26),
#  ('chemical', 26),
#  ('long', 25),
#  ('lung', 25),
#  ('sound', 24),
#  ('hard', 22),
#  ('short', 22),
#  ('need', 22),
#  ('make', 22),
#  ('clear', 20),
#  ('try', 20),
#  ('bad', 20),
#  ('weird', 20),
#  ('talk', 20),
#  ('body', 19),
#  ('say', 19),
#  ('style', 19),
#  ('graphic', 19),
#  ('wish', 18),
#  ('tell', 18),
#  ('fast', 18),
#  ('lot', 17),
#  ('s', 17),
#  ('point', 17),
#  ('use', 17),
#  ('thing', 16),
#  ('kid', 16),
#  ('attention', 16),
#  ('explain', 16),
#  ('look', 15),
#  ('color', 15),
#  ('specific', 15),
#  ('company', 14),
#  ('narrator', 14),
#  ('show', 14),
#  ('want', 14),
#  ('cartoon', 14),
#  ('word', 14),
#  ('effect', 14),
#  ('visual', 14),
#  ('    ', 13),
#  ('stop', 13),
#  ('harmful', 13),
#  ('time', 13),
#  ('like', 13),
#  ('confusing', 13),
#  ('young', 12),
#  ('see', 12),
#  ('virus', 12),
#  ('detail', 12),
#  ('source', 11),
#  ('guy', 11),
#  ('harm', 10),
#  ('pretty', 10),
#  ('evidence', 10),
#  ('care', 10),
#  ('art', 10),
#  ('maybe', 10),
#  ('unclear', 10),
#  ('eye', 10),
#  ('help', 10),
#  ('proof', 10),
#  ('target', 9),
#  ('annoying', 9),
#  ('catch', 9),
#  ('stuff', 9),
#  ('fine', 9),
#  ('scare', 9),
#  ('info', 9),
#  ('lie', 8),
#  ('adult', 8),
#  ('include', 8),
#  ('vaping', 8),
#  ('smoke', 8),
#  ('appeal', 8),
#  ('person', 8),
#  ('well', 8),
#  ('bore', 8),
#  ('covid', 8),
#  ('music', 8),
#  ('throw', 8),
#  ('relatable', 8),
#  ('scary', 8),
#  ('fear', 8),
#  ('present', 8),
#  ('statistic', 8),
#  ('away', 8),
#  ('quit', 8),
#  ('easy', 7),
#  ('speak', 7),
#  ('provide', 7),
#  ('lack', 7),
#  ('grab', 7),
#  ('take', 7),
#  ('claim', 7),
#  ('slow', 7),
#  ('believe', 7),
#  ('tactic', 7),
#  ('mention', 6),
#  ('change', 6),
#  ('great', 6),
#  ('name', 6),
#  ('real', 6),
#  ('school', 6),
#  ('watch', 6),
#  ('add', 6),
#  ('tone', 6),
#  ('cheesy', 6),
#  ('opinion', 6),
#  ('child', 6),
#  ('bland', 6),
#  ('childish', 6),
#  ('big', 6),
#  ('convince', 6),
#  ('hear', 6),
#  ('actually', 5),
#  ('clearly', 5),
#  ('straight', 5),
#  ('actor', 5),
#  ('suppose', 5),
#  ('audio', 5),
#  ('annoy', 5),
#  ('focus', 5),
#  ('campaign', 5),
#  ('probably', 5),
#  ('give', 5),
#  ('general', 5),
#  ('cringe', 5)]

# %%
#Edited list - excluding spaces, vape because vape is just the topic of the videos, and dislikes because just reiterating question
words = dislikes_df['Text_Token']
allwords = []
for wordlist in words:
    if "  " not in wordlist and "    " not in wordlist and "dislike" not in wordlist and "s" not in wordlist and "vape" not in wordlist:
        allwords += wordlist

# %%
#Create word cloud
mostcommon = FreqDist(allwords).most_common(50)
wordcloud = WordCloud(width=600, height=300,
background_color='white').generate(str(mostcommon))
fig = plt.figure(figsize=(20,6.5), facecolor='white')
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.title('Top 50 Most Common Words - Dislikes', fontsize=28)
plt.tight_layout(pad=0)
plt.show()

# %%
mostcommon_small = FreqDist(allwords).most_common(30)
x, y = zip(*mostcommon_small)
        
word_bar(x,y,(20,8),color_palette)
plt.style.use('seaborn-colorblind')
plt.title('Top 30 Most Common Words - Dislikes')
plt.ylabel('Count of Words')
plt.show()

# %% [markdown]
# #### Notes:
# * Top words in dislikes feedback
#     * little
#     * kind
#     * know
#     * good, people
#     * understand
#     * weird
# * These are harder to make out any pattern alone -- 2 or 3 n-grams might be more telling
# * Might remove 'kind', 'bit','go','like' in preprocessing

# %% [markdown]
# ### Step 6: Sentiment Analysis <a class="anchor" id="6"></a>
# Source: Sentiment Analysis code adapted from Towards Data Science article by Kamil Mysiak at https://towardsdatascience.com/nlp-part-3-exploratory-data-analysis-of-text-data-1caa8ab3f79d retrieved in January, 2021.
# * Sentiment analysis is used to measure the sentiment in text ranging from -1 (negative sentiment) to 1 (positive sentiment).

# %% [markdown]
# #### Sentiment Analysis of 'Likes' Feedback

# %%
likes_df['sentiment'] = likes_df['Text_Lemmas'].apply(lambda x:
TextBlob(x).sentiment.polarity)
likes_df = likes_df.sort_values(by='sentiment', ascending=False)

# %%
#Average sentiment score for 'Likes'
np.mean(likes_df['sentiment'])
# Out:
# 0.06773597608978217

# %%
#View distribution box plot
plt.boxplot(likes_df['sentiment'])
plt.title('Sentiment Scores - Likes')
plt.ylabel('Sentiment Score')
plt.show()

# %%
#View distribution histogram
plt.hist(likes_df['sentiment'], color='navy')
plt.style.use('seaborn-colorblind')
plt.title('Sentiment Score Distribution - Likes')
plt.ylabel('Sentiment Score')
plt.show()

# %% [markdown]
# #### Sentiment Analysis of 'Dislikes' Feedback

# %%
dislikes_df['sentiment'] = dislikes_df['Text_Lemmas'].apply(lambda x:
TextBlob(x).sentiment.polarity)
dislikes_df = dislikes_df.sort_values(by='sentiment', ascending=False)

# %%
#Average sentiment score for 'Dislikes'
np.mean(dislikes_df['sentiment'])
# Out:
# 0.014343452443365755

# %%
#View distribution box plot
plt.boxplot(dislikes_df['sentiment'])
plt.title('Sentiment Scores - Dislikes')
plt.ylabel('Sentiment Score')
plt.show()

# %%
#View distribution histogram
plt.hist(dislikes_df['sentiment'], color='navy')
plt.style.use('seaborn-colorblind')
plt.title('Sentiment Score Distribution - Dislikes')
plt.ylabel('Sentiment Score')
plt.show()

# %% [markdown]
# #### Notes:
# * Likes feedback has higher average sentiment score and is skewed slightly more positive than Dislikes feedback at .07 vs. .01.
# * This is expected and does not provide additional information, so sentiment analysis may not be very helpful.

# %% [markdown]
# ### Step 7: Summary & Next Steps <a class="anchor" id="7"></a>

# %% [markdown]
# #### Sample Summary:
# * n=724 survey participants
# * Participant age range from 13-19, with an average age of 16.7 years, and median age of 17 years.
# * The sample is skewed toward females at 64% and White/Caucasian participants at 72.2% (although this somewhat reflects the regional race distribution).
# * The most highly represented target audience segments are segments 1, 4, and 5, making up nearly 50% of the sample.
# * In terms participant location, nearly 3/4 live in an urban area, and the regional distribution is fairly event at 46% vs. 54%.
#
# #### Text Frequency Analysis Summary:
# * The most commonly used words used in explaining the message of the ads included vape, company, virus, stop, people, bad, teen, smoke, lie, lung, and harmful which relate well to the ad themes of chemicals in vapes, vulnerability to viruses and illnesses from vaping, and deception by vape companies.
# * The most common words used to describe what participants liked about the ads included animation, message, show, fact, informative, visual, point, and graphic which indicates that participants most liked the visual aspects of the ads as well as the information provided in them.
# * The most common words used to describe what participants did not like about the ads included kind, little, know, people, good, understand, information, animation, long and think. It’s unclear what the theme might be at this point. Consider processing 2 or 3 n-grams.
#
# #### Sentiment Analysis Summary:
# * The average sentiment score for feedback regarding what participants liked about the ads was .07 which is pretty low. However, the average sentiment score for feedback regarding what participants did not like about the ads was .01.
# * Sentiment scores for feedback regarding both likes and dislikes were heavily concentrated around the mean with a slightly more positive skew for / tail for feedback regarding likes.

# %% [markdown]
# #### Next Steps:
# * Based on the EDA, it seems topics would be more appropriate if three models were developed (one for each question — message, likes, and dislikes) as these questions have distinct feedback and frequent words related to the ads like ‘vapes’ might water down meaningful insights about the aspects of the ads that participants most liked and disliked.
# * The EDA of the ad feedback text was conducted using a combination of space, gensim, and word cloud stopwords. For preprocessing, consider testing whether some of these stop words may be removed to improve the term frequency analysis prior to training the topic model.
#     * May want to remove the words ‘nothing’, ‘none’, ‘everything’, and ‘anything’ from the stop words list so they are included in training of the models for the likes and dislikes. No positive or negative feedback regarding an ad is actually helpful information.
#     * For the message model, consider adding ’vape’ to the stop words list as it is related to all and commonly used.
#     * For the likes model, consider adding ‘like’ to the stop words list as it is redundant.
#     * For the dislikes model, consider adding ‘kind’, ‘bit’, ‘go’ and like to the stop words list.
# * While the sentiment analysis can be helpful in ad feedback, it does not appear to be appropriate for these particular questions. If the question was more vague like ‘What did you think of this ad?’, it might be more valuable.
